# %%
##2、使用pandas库里面的read_excel函数读取excecl文件，并展示数据前5行
import pandas as pd

data_yzw = pd.read_excel('D:\Developer\JetBrains\www.jetbrains.com\JetBrainsDemo\PycharmP\Crawler\yzw\运动医学-研招网专业信息.xls',
                              sheet_name="Sheet1")
data_yzw[:5]
# Out:
#                        id    招生单位 院校特性     院系所            专业  \
# 0  1125821021100216001001    大连大学  NaN  新华临床学院  (100216)运动医学
# 1  9110221000100216221001  解放军医学院  NaN  不区分院系所  (100216)运动医学
# 2  9110221000100216051001  解放军医学院  NaN  不区分院系所  (100216)运动医学
# 3  9110221000100216041001  解放军医学院  NaN  不区分院系所  (100216)运动医学
# 4  1004321000100216401001  北京体育大学  211  不区分院系所  (100216)运动医学
#
#                                          研究方向 学习方式        拟招生人数  \
# 0                                 (00)不区分研究方向  全日制   专业：2(不含推免)
# 1  (22)髋膝关节运动损伤疾病的诊断与治疗；肌腱病发病机制的研究；骨科内植物材料的研发  全日制   专业：2(不含推免)
# 2                          (05)关节疾病、运动医学、骨科材料  全日制   专业：2(不含推免)
# 3                (04)运动医学，关节镜微创治疗肩、肘、膝、踝等运动损伤  全日制   专业：2(不含推免)
# 4                               (40)运动与慢性疾病研究  全日制  专业：14(不含推免)
#
#                 业务课一   业务课二          外语           政治 所在地    专业代码 指导老师  门类  \
# 0          (610)西医综合  (--)无  (201)英语（一）  (101)思想政治理论  辽宁  100216  NaN  医学
# 1  (306)临床医学综合能力（西医）  (--)无  (201)英语（一）  (101)思想政治理论  北京  100216  李春宝  医学
# 2  (306)临床医学综合能力（西医）  (--)无  (201)英语（一）  (101)思想政治理论  北京  100216  李众利  医学
# 3  (306)临床医学综合能力（西医）  (--)无  (201)英语（一）  (101)思想政治理论  北京  100216  刘玉杰  医学
# 4    (624)临床医学综合（西医）  (--)无  (201)英语（一）  (101)思想政治理论  北京  100216  NaN  医学
#
#    一级学科   备注
# 0  临床医学  NaN
# 1  临床医学  NaN
# 2  临床医学  NaN
# 3  临床医学  NaN
# 4  临床医学  NaN

# %%
data_yzw.iloc[1, 1]

# %%
## 使用pandas库里面的read_csv函数读取csv文件，并展示数据前5行。
data_csv = pd.read_csv("D:\Developer\JetBrains\www.jetbrains.com\JetBrainsDemo\PycharmP\Crawler\yzw\yzw.csv",
                       encoding="gbk")
data_csv[:5]
# Out:
#                        id      招生单位 院校特性        院系所                专业  \
# 0  1021621004081200001001      燕山大学  NaN  信息科学与工程学院  (081200)计算机科学与技术
# 1  1183221450081200041001    河北经贸大学  NaN     信息技术学院  (081200)计算机科学与技术
# 2  1183221450081200031001    河北经贸大学  NaN     信息技术学院  (081200)计算机科学与技术
# 3  1008421005081200001001  河北建筑工程学院  NaN     信息工程学院  (081200)计算机科学与技术
# 4  1008621006081200031001    河北农业大学  NaN  信息科学与技术学院  (081200)计算机科学与技术
#
#                研究方向 学习方式        拟招生人数        业务课一            业务课二          外语  \
# 0         (00)不区分方向  全日制  专业：69(不含推免)  (301)数学（一）  (408)计算机学科专业基础  (201)英语（一）
# 1         (04)计算与管理  全日制  专业：16(不含推免)  (301)数学（一）       (807)数据结构  (201)英语（一）
# 2  (03)图像视频处理与多媒体技术  全日制  专业：16(不含推免)  (301)数学（一）       (807)数据结构  (201)英语（一）
# 3       (00)不区分研究方向  全日制  专业：29(不含推免)  (301)数学（一）  (806)计算机专业基础综合  (201)英语（一）
# 4    (03)计算机网络与信息安全  全日制   专业：9(不含推免)  (301)数学（一）      (807)计算机网络  (201)英语（一）
#
#             政治 所在地   专业代码                    指导老师  门类      一级学科  \
# 0  (101)思想政治理论  河北  81200  可登录燕山大学研究生院网站导师信息栏目查看。  工学  计算机科学与技术
# 1  (101)思想政治理论  河北  81200                   不区分导师  工学  计算机科学与技术
# 2  (101)思想政治理论  河北  81200                   不区分导师  工学  计算机科学与技术
# 3  (101)思想政治理论  河北  81200                     NaN  工学  计算机科学与技术
# 4  (101)思想政治理论  河北  81200                     NaN  工学  计算机科学与技术
#
#                                                   备注
# 0                      招生名额或因计划正式下达、接收推免生数量等原因造成增减变化
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  复试科目：计算机基础理论与技术；后期专业拟考试招生人数因正式招生计划下达或实际录取推免硕士生...

# %%
## 4、使用OpenCV库读取图片并展示，输出图片的尺寸、形状、数据类型。
import cv2

cv2_image = cv2.imread('E:\ChromeDownload\Sheya\897028310.jpg')
cv2.imshow('cv2_image', cv2_image)
# cv2.waitKey()
# cv2.destroyAllWindows()
print(cv2_image.shape)
print(type(cv2_image))

# %%
## 使用PIL库读取图片并使用.array函数转换为矩阵形式，使用matplotlib包展示图片，输出转换图片的尺寸、形状、数据类型。
import matplotlib.pyplot as plt
import numpy as np

img_plt = plt.imread('D:\Developer\ToneC\IDMDL\928679220.jfif')
img_plt_array = np.array(img_plt)
#print(img_plt_array)
plt.imshow(img_plt)
plt.show()
print(img_plt.shape)
print(type(img_plt))
# Out:
# (2000, 1234, 3)
# <class 'numpy.ndarray'>
